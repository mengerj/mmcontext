# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mmcontext.eval.utils import load_evaluation_results

df_long = load_evaluation_results("../../outputs/evaluation_results_100k_text_unfrozen.csv")

# %%
from mmcontext.pl.metric_plots import plot_evaluation_results

scib_subset = {"scib_Bio_Conservation_Score", "scib_Batch_Integration_Score", "scib_Overall_Score"}
plot_evaluation_results(
    "../../outputs/evaluation_results_100k_text_unfrozen.csv", label_fontsize=18, legend_fontsize=20, title_fontsize=20
)

# %%
from mmcontext.pl.metric_plots import create_model_rank_table

# rank the evaluation reslts
df = create_model_rank_table("../../outputs/evaluation_results_100k_text_unfrozen.csv")

# %%
import logging

logger = logging.getLogger(__name__)

# %%
from mmcontext.pl.metric_plots import plot_evaluation_summary

plot_evaluation_summary(
    "../../outputs/evaluation_results.csv",
    label_fontsize=24,
    legend_fontsize=24,
    title_fontsize=28,
    eval_results_figsize=(18, 12),
    mean_ranks_figsize=(14, 8),
    dpi=600,
    save_format="svg",
    save_dir="figs",
    save_plot=True,
)
# Out:
# /Users/mengerj/repos/mmcontext/src/mmcontext/pl/metric_plots.py:372: UserWarning:
#
# The `scale` parameter is deprecated and will be removed in v0.15.0. You can now control the size of each plot element using matplotlib `Line2D` parameters (e.g., `linewidth`, `markersize`, etc.).

# %%
from mmcontext.eval.utils import transform_to_funkyheatmap_format

df_wide, column_info, column_groups_df = transform_to_funkyheatmap_format(df_long)

# %%
# acess second column first row
df_wide.iloc[0, 3] = 0.8

# %%
from mmcontext.pl.plotting import create_funky_heatmap

create_funky_heatmap(df_wide, column_info, column_groups_df)
# Out:
# /Users/mengerj/repos/mmcontext/.venv/lib/python3.11/site-packages/funkyheatmappy/verify_column_info.py:79: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['id' 'model_short_name' 'dataset_short_name'
#  'modality_gap_irrelevant_score' 'full_comparison_score'
#  'annotation_accuracy' 'zero_shot_macro_auc']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   column_info.loc[pd.isna(column_info["id_color"]), "id_color"] = column_info["id"] # if nan, replace by id, except if text or image
# /Users/mengerj/repos/mmcontext/.venv/lib/python3.11/site-packages/funkyheatmappy/verify_column_info.py:89: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['id' 'model_short_name' 'dataset_short_name'
#  'modality_gap_irrelevant_score' 'full_comparison_score'
# ...

# %%
import numpy as np

# add id_color column with nans to column_info
column_info["id_color"] = np.nan

# %%
df_wide.index
# Out:
# Index([0, 4], dtype='int64')
