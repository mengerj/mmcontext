# %% [markdown]
# # MMContext Model Usage Tutorial
#
# This notebook demonstrates how to use your trained MMContext model for generating embeddings from text descriptions.
#
# ## 🚨 Important: Loading Requirements
#
# This model uses a custom architecture and **requires `trust_remote_code=True`** to load properly.

# %% [markdown]
# ## Installation
# (Install ipykernel into your virtual env first)
# First, make sure you have the required packages installed:

# %%
# Install required packages
# %pip install sentence-transformers pandas datasets anndata
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#   Using cached scanpy-1.11.4-py3-none-any.whl.metadata (9.2 kB)
# ...
#   Using cached matplotlib-3.10.6-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# ...
#   Using cached patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached session_info2-0.2.2-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached statsmodels-0.14.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.5 kB)
# ...
#   Using cached umap_learn-0.5.9.post2-py3-none-any.whl.metadata (25 kB)
# ...

# %% [markdown]
# ## Loading the Model
#
# ⚠️ **Critical**: Always use `trust_remote_code=True` when loading this model.

# %%
from sentence_transformers import SentenceTransformer

# Replace with your actual model repository ID
# model_id = "jo-mengr/your-model-name"  # Update this!
model_id = "jo-mengr/mmcontext-pubmedbert-gs-cxg_test-v6"

# ✅ CORRECT: Load with trust_remote_code=True
model = SentenceTransformer(model_id, trust_remote_code=True)

print("✅ Model loaded successfully!")
print(f"Model: {model}")
# Out:
# A new version of the following files was downloaded from https://huggingface.co/jo-mengr/mmcontext-pubmedbert-gs-cxg_test-v6:
# - file_utils.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jo-mengr/mmcontext-pubmedbert-gs-cxg_test-v6:
# - omicsencoder.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jo-mengr/mmcontext-pubmedbert-gs-cxg_test-v6:
# - onehot.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %% [markdown]
# ## Basic Usage: Text Embeddings
#
# Generate embeddings for cell type descriptions or any biological text:

# %%
# Example cell type descriptions
texts = [
    "T cell",
    "B cell",
    "Natural killer cell",
    "Macrophage",
    "Dendritic cell",
    "Neutrophil",
    "Monocyte",
    "Plasma cell",
]

# Generate embeddings
embeddings = model.encode(texts)

print(f"Generated embeddings for {len(texts)} texts")
print(f"Embedding shape: {embeddings.shape}")
print(f"Embedding dimension: {embeddings.shape[1]}")
# Out:
# Generated embeddings for 8 texts
# Embedding shape: (8, 768)
# Embedding dimension: 768

# %% [markdown]
# ## Encoding omics data
# 1. If you want to encode new data, you have to compute the initial embeddings by yourself.
# You have to store the embeddings for each cell in the obsm layer of an adata object.
#
# # For the best performing model, based on the gs10k initial embedding (gene selection for 10k genes), this is very straightforward as you can subset your adata object based on a list of genes, which you can find in the [mmcontext GitHub repo](https://github.com/mengerj/mmcontext).

# %%
# 1. verify which type of initial embeddings the model expects
model[0].registered_data_origin
# Out:
# 'gs'

# %%
import scanpy as sc

adata = sc.datasets.pbmc3k()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import scanpy as sc
#       2 adata = sc.datasets.pbmc3k()
#
# ModuleNotFoundError: No module named 'scanpy'
